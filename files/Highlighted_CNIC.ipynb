# %%
from pytesseract import *
import cv2

# Define the path to the input image
image_path = "image.jpg"

# Create a dictionary to mimic command-line arguments
args = {
    "image": image_path,
    "min_conf": 0  # You can set the minimum confidence value here
}

# Load the input image and convert it to RGB
images = cv2.imread(args["image"])
rgb = cv2.cvtColor(images, cv2.COLOR_BGR2RGB)
results = pytesseract.image_to_data(rgb, output_type=Output.DICT)

# Then loop over each of the individual text localizations
for i in range(0, len(results["text"])):
    # We can then extract the bounding box coordinates
    x = results["left"][i]
    y = results["top"][i]
    w = results["width"][i]
    h = results["height"][i]
    
    # We will also extract the OCR text itself along with the confidence of the text localization
    text = results["text"][i]
    conf = int(results["conf"][i])
    
    # Filter out weak confidence text localizations
    if conf > args["min_conf"]:
        # We will display the confidence and text to our terminal
        print("Confidence: {}".format(conf))
        print("Text: {}".format(text))
        print("")
        
        # We then strip out non-ASCII text so we can draw the text on the image using OpenCV
        text = "".join(text).strip()
        cv2.rectangle(images,
                      (x, y),
                      (x + w, y + h),
                      (0, 0, 255), 2)
        cv2.putText(images,
                    text,
                    (x, y - 10),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1.2, (0, 255, 255), 3)

# After all, we will show the output image
cv2.imshow("Image", images)
cv2.waitKey(0)
# Out:
# Confidence: 86
# Text: ISLAMIC
#
# Confidence: 96
# Text: REPUBLIC
#
# Confidence: 96
# Text: OF
#
# Confidence: 88
# Text: PAKISTAN
#
# Confidence: 95
# Text: PAKISTAN
#
# Confidence: 71
# Text: National
#
# Confidence: 91
# Text: identity
#
# Confidence: 88
# Text: card
#
# Confidence: 24
# Text: aC}
#
# Confidence: 96
# Text: Name
#
# Confidence: 96
# Text: Ahsan
#
# Confidence: 95
# Text: Tariq
#
# Confidence: 22
# Text: ee
#
# Confidence: 32
# Text: 2
#
# Confidence: 35
# Text: a
#
# Confidence: 18
# Text: Ol:
#
# Confidence: 41
# Text: Cs
#
# Confidence: 36
# Text: Ne
#
# Confidence: 23
# Text: I
#
# Confidence: 96
# Text: Gender
#
# Confidence: 96
# Text: of
#
# Confidence: 96
# Text: Stay
#
# Confidence: 28
# Text: =
#
# Confidence: 95
# Text: Pakistan
#
# Confidence: 71
# Text: |
#
# Confidence: 71
# Text: Date
#
# Confidence: 91
# Text: of
#
# Confidence: 62
# Text: Birth
#
# Confidence: 93
# Text: |
#
# Confidence: 35
# Text: 07.07.2004
#
# Confidence: 96
# Text: Date
#
# ...

# %%
from pytesseract import *
import cv2
import numpy as np

# Define the path to the input image
image_path = "image.jpg"

# Load the input image
image = cv2.imread(image_path)

# Convert the image to grayscale for better OCR accuracy
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Perform OCR on the entire image
text = pytesseract.image_to_string(gray, lang='eng')

# Get the bounding box coordinates of each word/character
detections = pytesseract.image_to_boxes(gray)

# Display the extracted text
print("Extracted Text:")
print(text)

# Draw bounding boxes around each word/character and highlight the text
for detection in detections.splitlines():
    detection = detection.split()
    x, y, w, h = int(detection[1]), int(detection[2]), int(detection[3]), int(detection[4])
    cv2.rectangle(image, (x, h), (w, y), (0, 255, 0), 2)

# Create a fullscreen window for displaying the image
cv2.namedWindow("Image", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Image", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

# Display the image with highlighted text
cv2.imshow("Image", image)

# Wait for a key press and then close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Extracted Text:
# Name
#
# Ahsan Tariq
#
# Father Name
#
# Tariq Mehmood
#
# Gender } Country of Stay
# Mj Pakistan
#
# identity Number | Date of Birth
# 31102-7130971-9 | 07.07.2004
#
# Date of Issue | Date of Expiry
#
# 08.08.2022 | 08.08.2032 jaar nanan

# %%
from pytesseract import *
import cv2
import numpy as np

# Define the path to the input image
image_path = "image.jpg"

# Load the input image
image = cv2.imread(image_path)

# Convert the image to grayscale for better OCR accuracy
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Perform OCR on the entire image
text = pytesseract.image_to_string(gray, lang='eng')

# Get the bounding box coordinates of each word/character
detections = pytesseract.image_to_boxes(gray)

# Display the extracted text
print("Extracted Text:")
print(text)

# Draw bounding boxes around each word/character and highlight the text on the image
for detection in detections.splitlines():
    detection = detection.split()
    x, y, w, h = int(detection[1]), int(detection[2]), int(detection[3]), int(detection[4])
    cv2.rectangle(image, (x, h), (w, y), (0, 255, 0), 2)

# Create a fullscreen window for displaying the image
cv2.namedWindow("Image", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Image", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

# Display the image with highlighted text
cv2.imshow("Image", image)

# Wait for a key press and then close the window
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Extracted Text:
# Name
#
# Ahsan Tariq
#
# Father Name
#
# Tariq Mehmood
#
# Gender } Country of Stay
# Mj Pakistan
#
# identity Number | Date of Birth
# 31102-7130971-9 | 07.07.2004
#
# Date of Issue | Date of Expiry
#
# 08.08.2022 | 08.08.2032 jaar nanan
